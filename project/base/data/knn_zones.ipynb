# %%
# %%time

import pandas as pd

# import training csv data
df = pd.read_csv("data.csv")

# df.head(5)


def id_to_int(i):
    return ord(i)


df['b1'] = df['b1'].apply(id_to_int)
df['b2'] = df['b2'].apply(id_to_int)
df['b3'] = df['b3'].apply(id_to_int)


X = df.drop(columns=['zone'])
y = df['zone']


df
# Out:
# CPU times: user 14.4 ms, sys: 2.12 ms, total: 16.5 ms
# Wall time: 13.9 ms
#       zone  b1  b2  b3  b1r  b2r  b3r
# 0        1  69  70  65  -79  -85  -63
# 1        1  69  70  65  -80  -85  -59
# 2        1  69  70  65  -71  -84  -63
# 3        1  69  70  65  -71  -84  -63
# 4        1  69  70  65  -71  -85  -59
# ...    ...  ..  ..  ..  ...  ...  ...
# 1051     8  79  80  71  -68  -88  -89
# 1052     8  79  80  71  -68  -80  -89
# 1053     8  79  80  70  -68  -81  -90
# 1054     8  79  80  70  -71  -88  -90
# 1055     8  79  80  70  -68  -81  -90
#
# [1056 rows x 7 columns]

# %%
# %%time
# no need to process, data is clean as bean
from sklearn.model_selection import train_test_split
# train test split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)
print("shapes:", X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# shapes: (844, 6) (844,) (212, 6) (212,)
# CPU times: user 7.65 ms, sys: 1.88 ms, total: 9.53 ms
# Wall time: 7.16 ms

# %%
# %%time

from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import roc_auc_score

knn =  KNeighborsClassifier(leaf_size=1, n_neighbors=8, p=2)
knn.fit(X,y)


#Predict test data set.
y_pred = knn.predict(X_test)#Checking performance our model with classification report.
print(classification_report(y_test, y_pred))#Checking performance our model with ROC Score.
# roc_auc_score(y_test, y_pred)
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        23
#            2       1.00      1.00      1.00        27
#            3       0.94      1.00      0.97        29
#            4       0.85      0.79      0.81        14
#            5       0.88      0.79      0.83        19
#            6       0.91      1.00      0.95        20
#            7       0.97      1.00      0.98        28
#            8       1.00      0.96      0.98        52
#
#     accuracy                           0.96       212
#    macro avg       0.94      0.94      0.94       212
# weighted avg       0.96      0.96      0.96       212
#
# CPU times: user 48.4 ms, sys: 2.33 ms, total: 50.7 ms
# Wall time: 46.8 ms

# %%
# one row only
xrow = X_test.head(12)
# print(xrow)
pred = knn.predict(xrow)

i = 0
for r in xrow.values:
    print(chr(r[0]),chr(r[1]),chr(r[2]),r[3],r[4],r[5], '->',pred[i])
    i+=1
# Out:
# E P G -84 -78 -64 -> 5
# G F P -69 -76 -69 -> 5
# O P F -65 -88 -87 -> 8
# F O G -76 -84 -69 -> 5
# O F P -71 -86 -88 -> 8
# P F G -70 -85 -77 -> 6
# O P F -63 -82 -88 -> 8
# O P F -67 -88 -87 -> 8
# P O G -72 -87 -79 -> 6
# A E F -61 -64 -77 -> 2
# G P F -69 -70 -76 -> 5
# E F G -73 -65 -71 -> 4
